# %% [markdown]
# # Models metrics comparison

# %%
import os
import sys
import json

sys.path.insert(0, '../src')

import numpy as np
import pandas as pd

from loader import ImagesDataset

# %%
SEED = 11
rng = np.random.default_rng(SEED)

# %%
DATA_PATH = '../images'
SHAPE = (128, 128, 3)

dataset = ImagesDataset(path=DATA_PATH, preload=False, encode_labels=True)
classes = dataset.label_encoder.classes_.tolist()
n_classes = len(classes)

dataset.split(shuffle=SEED)

train_uniques, train_counts = np.unique(dataset.labels[dataset.train.indices], return_counts=True)
train_shares = train_counts / train_counts.sum()
# Out:
# 100%|████████████████████████████████████████████| 9/9 [00:00<00:00, 461.35it/s]

# %%
classwise_metrics = ['precision', 'recall']
general_metrics = ['accuracy', 'f1_score']
metrics_names = classwise_metrics + general_metrics

metrics = {name: {} for name in metrics_names}

METRICS_PATH = '../metrics'
for file in sorted(os.listdir(METRICS_PATH)):
    if not file.endswith('.json'):
        continue

    file_path = os.path.join(METRICS_PATH, file)
    with open(file_path, 'r') as f:
        metrics_dict = json.load(f)
    
    model_name = file.split('.')[0].split('_')[1]
    for name in metrics_names:
        metrics[name][model_name] = metrics_dict[name]

# %%
html = ''

styles = [
    {
        'selector': "caption",
        'props': [
            ('font-family', 'monospace'),
            ("font-size", "150%")
        ]
    },
    {
        'selector': "tbody",
        'props': [
            ('font-family', 'monospace'),
            ('text-align', 'right'),
        ]
    },
]

for metrics_name in metrics_names:
    metrics_dict = metrics[metrics_name]

    if metrics_name in classwise_metrics:
        metrics_dict = {'shares': train_shares, **metrics_dict}
        index = classes
    else:
        metrics_dict = {'shares': 1 / n_classes, **metrics_dict}
        index = ['\u00A0' * 3 + 'altogether']

    df = pd.DataFrame(data=metrics_dict, index=index)
    formatter = lambda value: f"{(value * 100).round(1)}"
    styled_df = df.style.background_gradient('RdYlGn', vmin=0, vmax=1, axis=0).format(formatter).set_caption(metrics_name).set_table_styles(styles)
    display(styled_df)
    
    html += styled_df.render()
    
with open('../report/report.html', 'w') as f:
    f.write(html)
# Out:
# <style  type="text/css" >
#     #T_d7874870_5166_11ed_be59_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_d7874870_5166_11ed_be59_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_d7874870_5166_11ed_be59_0242ac110002row0_col0{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col1{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col3{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col5,#T_d7874870_5166_11ed_be59_0242ac110002row7_col5{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row0_col6,#T_d7874870_5166_11ed_be59_0242ac110002row2_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col1{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col2{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col3{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col4{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col5{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row1_col6{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col1{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col3{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col4{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col5{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row2_col6{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col0,#T_d7874870_5166_11ed_be59_0242ac110002row4_col1{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col1{
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col2{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col4{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col5{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row3_col6,#T_d7874870_5166_11ed_be59_0242ac110002row6_col3{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col0{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col2{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col3{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col4{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col5,#T_d7874870_5166_11ed_be59_0242ac110002row7_col3{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row4_col6{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col0{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col1{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col2{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col3{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col4{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col5{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row5_col6{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row6_col0{
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row6_col1,#T_d7874870_5166_11ed_be59_0242ac110002row6_col2{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row6_col4{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row6_col5{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row6_col6{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row7_col0{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row7_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row7_col2{
#             background-color:  #f67c4a;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row7_col4{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_d7874870_5166_11ed_be59_0242ac110002row7_col6{
#             background-color:  #98d368;
#             color:  #000000;
#         }</style><table id="T_d7874870_5166_11ed_be59_0242ac110002" ><caption>precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KMeans</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7874870_5166_11ed_be59_0242ac110002level0_row0" class="row_heading level0 row0" >ArtDeco</th>
#                         <td id="T_d7874870_5166_11ed_be59_0242ac110002row0_col0" class="data row0 col0" >4.7</td>
#                         <td id="T_d7874870_5166_11ed_be59_0242ac110002row0_col1" class="data row0 col1" >7.1</td>
#                         <td id="T_d7874870_5166_11ed_be59_0242ac110002row0_col2" class="data row0 col
# <style  type="text/css" >
#     #T_d78dc81c_5166_11ed_be59_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_d78dc81c_5166_11ed_be59_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col0{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col1{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col3,#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col5,#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col6,#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col6,#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row0_col4{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col1{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col2{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col4{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col5{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row1_col6{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col1{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col2{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col3,#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col6{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col4{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row2_col5{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col0{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col1,#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col0{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col2{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col3{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col4{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row3_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col0{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col3,#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col5{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col5{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row4_col6{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col0{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col1,#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col1,#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col1{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col3,#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col6{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col4,#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col3{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row5_col5{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col0{
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col2{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col3,#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col6{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row6_col5{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col2{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col4{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_d78dc81c_5166_11ed_be59_0242ac110002row7_col6{
#             background-color:  #69be63;
#             color:  #000000;
#         }</style><table id="T_d78dc81c_5166_11ed_be59_0242ac110002" ><caption>recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KMeans</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d78dc81c_5166_11ed_be59_0242ac110002level0_row0" class="row_heading level0 row0" >ArtDeco</th>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col0" class="data row0 col0" >4.7</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col1" class="data row0 col1" >8.3</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col2" class="data row0 col2" >0.0</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col3" class="data row0 col3" >50.0</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col4" class="data row0 col4" >30.0</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col5" class="data row0 col5" >50.0</td>
#                         <td id="T_d78dc81c_5166_11ed_be59_0242ac110002row0_col6" class="data row0 col6" >50.0</td>
# <style  type="text/css" >
#     #T_d79272c2_5166_11ed_be59_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_d79272c2_5166_11ed_be59_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col1{
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col2{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col3{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col4{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col5{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_d79272c2_5166_11ed_be59_0242ac110002row0_col6{
#             background-color:  #b7e075;
#             color:  #000000;
#         }</style><table id="T_d79272c2_5166_11ed_be59_0242ac110002" ><caption>accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KMeans</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d79272c2_5166_11ed_be59_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col1" class="data row0 col1" >17.6</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col2" class="data row0 col2" >27.8</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col3" class="data row0 col3" >65.8</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col4" class="data row0 col4" >67.0</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col5" class="data row0 col5" >67.3</td>
#                         <td id="T_d79272c2_5166_11ed_be59_0242ac110002row0_col6" class="data row0 col6" >66.5</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_d795ef6a_5166_11ed_be59_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_d795ef6a_5166_11ed_be59_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col1{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col2{
#             background-color:  #fa9656;
#             color:  #000000;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col3{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_d795ef6a_5166_11ed_be59_0242ac110002row0_col6{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }</style><table id="T_d795ef6a_5166_11ed_be59_0242ac110002" ><caption>f1_score</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KMeans</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d795ef6a_5166_11ed_be59_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col1" class="data row0 col1" >14.2</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col2" class="data row0 col2" >26.2</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col3" class="data row0 col3" >64.5</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col4" class="data row0 col4" >62.3</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col5" class="data row0 col5" >65.2</td>
#                         <td id="T_d795ef6a_5166_11ed_be59_0242ac110002row0_col6" class="data row0 col6" >64.0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Conlusion

# %% [markdown]
# Clustering of embeddings via KMeans produces the highest metrics values so far, in both accuracy and F1 score. The latter is basically a harmonic mean of precision and recall, so with no extra assumptions about specific classes importance (e.g. errors on ArtDeco should be minimized at all costs).
#
# 🥇I conclude that VGG + KMeans combo is the best model among others.
#
# 🥈 The honorable second place goes to boosting via LGBM.
#
# 🥉Finally, third place is shared among VGG and EfficientNet. What's interesting about VGG here is that it deals slightly better with rare classes, like cartoon and ArtDeco.

# %% [markdown]
# ### Criticism

# %% [markdown]
# There are much more here to test and research. Among most important, yet not implemented ideas are:
#
# - cross-validation: metrics above are obtained on a single fixed seed and therefore estimate of model performance quality based solely on them is kinda weak;
# - augmentations: the dataset is small and even simple augmentations like flip, rotate, cutout, crop and noise might significantly enrich it and therefore, increase model generalizing capability and reduce overfitting;
# - massive hyper-parameters research: those one, fixed in presented experiment are obtained via minimized research on limited parameters domain;
# - algorithms: only a small subset of possible approaches is checked during this experiment — there are more architectures (i.e. with residual connections, attention modules) and clustering algorithms (i.e. TSNE, DBSCAN, SOM) that might perform better on given data
# - find more data: there are open dataset containing images of various styles (e.g. ArtGan). they might contribute a lot;
