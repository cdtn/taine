# %%
import os
import sys

sys.path.insert(0, '../src')

import numpy as np
import pandas as pd

from loader import ImagesDataset

# %%
SEED = 11
rng = np.random.default_rng(SEED)

# %%
DATA_PATH = '../images'
SHAPE = (128, 128, 3)

dataset = ImagesDataset(path=DATA_PATH, preload=False, encode_labels=True)
n_classes = dataset.label_encoder.classes_.size

dataset.split(shuffle=SEED)
# Out:
# 100%|████████████████████████████████████████████| 9/9 [00:00<00:00, 444.33it/s]

# %%
labels, counts = np.unique(dataset.labels[dataset.test.indices], return_counts=True)
shares = counts / counts.sum()

# %%
classwise_metrics = ['precision', 'recall']
general_metrics = ['accuracy', 'f1_score']
metrics_names = classwise_metrics + general_metrics

metrics = {name: {} for name in metrics_names}

METRICS_PATH = '../metrics'
for file in sorted(os.listdir(METRICS_PATH)):
    if file.startswith('.'):
        continue

    file_path = os.path.join(METRICS_PATH, file)
    metrics_dict = np.load(file_path, allow_pickle=True).item()
    
    model_name = file.split('.')[0].split('_')[1]
    for name in metrics_names:
        metrics[name][model_name] = metrics_dict[name]

# %%
html = ''

styles = [
    {
        'selector': "caption",
        'props': [
            ('font-family', 'monospace'),
            ("font-size", "150%")
        ]
    },
    {
        'selector': "tbody",
        'props': [
            ('font-family', 'monospace'),
            ('text-align', 'right'),
        ]
    },
]

for metrics_name in metrics_names:
    metrics_dict = metrics[metrics_name]

    if metrics_name in classwise_metrics:
        metrics_dict = {'shares': shares, **metrics_dict}
        index = labels
    else:
        metrics_dict = {'shares': 1 / n_classes, **{key: [value] for key, value in metrics_dict.items()}}
        index = ['\u00A0' * 3 + 'altogether']

    df = pd.DataFrame(data=metrics_dict, index=index)
    formatter = lambda value: f"{(value * 100).round(1)}"
    styled_df = df.style.background_gradient('RdYlGn', vmin=0, vmax=1, axis=0).format(formatter).set_caption(metrics_name).set_table_styles(styles)
    display(styled_df)
    
    html += styled_df.render()
    
with open('../report.html', 'w') as f:
    f.write(html)
# Out:
# <style  type="text/css" >
#     #T_1fff8fc4_50b1_11ed_9182_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_1fff8fc4_50b1_11ed_9182_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col0{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col1{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col3{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col5,#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col6,#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col5{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col6{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col0{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col1{
#             background-color:  #fdb365;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col2{
#             background-color:  #fdc574;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col3{
#             background-color:  #a9da6c;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col4{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col5{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row1_col6{
#             background-color:  #d3ec87;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col0{
#             background-color:  #e95538;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col1{
#             background-color:  #f36b42;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col3{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col4{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col5{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row2_col6{
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col0{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col1{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col2{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col3{
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col4{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col5,#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col3{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row3_col6{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col0,#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col1{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col2{
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col3{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col4{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col5{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row4_col6{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col0,#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col0{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col1{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col2{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col3{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col4{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row5_col5{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col1{
#             background-color:  #da362a;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col2{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col3{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col4{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col5{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row6_col6{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col0{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col2{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col4{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_1fff8fc4_50b1_11ed_9182_0242ac110002row7_col6{
#             background-color:  #daf08d;
#             color:  #000000;
#         }</style><table id="T_1fff8fc4_50b1_11ed_9182_0242ac110002" ><caption>precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KNN</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1fff8fc4_50b1_11ed_9182_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col0" class="data row0 col0" >4.2</td>
#                         <td id="T_1fff8fc4_50b1_11ed_9182_0242ac110002row0_col1" class="data row0 col1" >8.3</td>
#                         <td id=
# <style  type="text/css" >
#     #T_20060354_50b1_11ed_9182_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_20060354_50b1_11ed_9182_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_20060354_50b1_11ed_9182_0242ac110002row0_col0{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col1{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col3{
#             background-color:  #dff293;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col4{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col5,#T_20060354_50b1_11ed_9182_0242ac110002row6_col4{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row0_col6{
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col0{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col1{
#             background-color:  #fdc574;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col2{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col4{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col5{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row1_col6{
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col0{
#             background-color:  #e95538;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col1{
#             background-color:  #f36b42;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col2{
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col3{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col4{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col5{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row2_col6{
#             background-color:  #e6f59d;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col0{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col1{
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col2,#T_20060354_50b1_11ed_9182_0242ac110002row5_col2{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col3,#T_20060354_50b1_11ed_9182_0242ac110002row3_col5{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col4{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row3_col6{
#             background-color:  #daf08d;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col0{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col3{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col5{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row4_col6{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row5_col0,#T_20060354_50b1_11ed_9182_0242ac110002row6_col0{
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row5_col1{
#             background-color:  #be1827;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row5_col3{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row5_col4,#T_20060354_50b1_11ed_9182_0242ac110002row7_col6{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row5_col5,#T_20060354_50b1_11ed_9182_0242ac110002row5_col6{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row6_col1,#T_20060354_50b1_11ed_9182_0242ac110002row6_col2,#T_20060354_50b1_11ed_9182_0242ac110002row7_col0{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row6_col3{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row6_col5{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row6_col6{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row7_col1{
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row7_col2{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row7_col3,#T_20060354_50b1_11ed_9182_0242ac110002row7_col5{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_20060354_50b1_11ed_9182_0242ac110002row7_col4{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }</style><table id="T_20060354_50b1_11ed_9182_0242ac110002" ><caption>recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KNN</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20060354_50b1_11ed_9182_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_20060354_50b1_11ed_9182_0242ac110002row0_col0" class="data row0 col0" >4.2</td>
#                         <td id="T_20060354_50b1_11ed_9182_0242ac110002row0_col1" class="data row0 col1" >8.3</td>
#                         <td id="T_20060354_50b1_11ed_9182_0242ac110002row0_col2" class="data row0 col2" >0.0</td>
#                         <td id="T_20060354_50b1_11ed_9182_0242ac110002row0_col3" class="data row0 col3" >58.3</td>
#                         <td id="T_20060354_50b1_11ed_9182_0242ac110002row0_col4" class="data row0 col4" >30.0</td>
# <style  type="text/css" >
#     #T_200c0cfe_50b1_11ed_9182_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_200c0cfe_50b1_11ed_9182_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col1{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col2{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col3,#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col5{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col4{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col6{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }</style><table id="T_200c0cfe_50b1_11ed_9182_0242ac110002" ><caption>accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KNN</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_200c0cfe_50b1_11ed_9182_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col1" class="data row0 col1" >18.7</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col2" class="data row0 col2" >29.9</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col3" class="data row0 col3" >67.3</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col4" class="data row0 col4" >67.0</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col5" class="data row0 col5" >67.3</td>
#                         <td id="T_200c0cfe_50b1_11ed_9182_0242ac110002row0_col6" class="data row0 col6" >64.4</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_200fbcdc_50b1_11ed_9182_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_200fbcdc_50b1_11ed_9182_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col1{
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col2{
#             background-color:  #fa9656;
#             color:  #000000;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col3{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col4{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col6{
#             background-color:  #cbe982;
#             color:  #000000;
#         }</style><table id="T_200fbcdc_50b1_11ed_9182_0242ac110002" ><caption>f1_score</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >EFFICIENTNET</th>        <th class="col_heading level0 col5" >KNN</th>        <th class="col_heading level0 col6" >LGBM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_200fbcdc_50b1_11ed_9182_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col1" class="data row0 col1" >14.7</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col2" class="data row0 col2" >26.4</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col3" class="data row0 col3" >64.6</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col4" class="data row0 col4" >62.3</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col5" class="data row0 col5" >65.2</td>
#                         <td id="T_200fbcdc_50b1_11ed_9182_0242ac110002row0_col6" class="data row0 col6" >62.8</td>
#             </tr>
#     </tbody></table>

# %%
from IPython.display import HTML

disclaimer_0 = "<p>* values in 'shares' column are class frequencies in train dataset</p><style>p { font-size: 20px}p { font-family: Courier; }</style>"
disclaimer_1 = "<p>** all values are normalized to [0, 100] range</p><style>p { font-size: 20px}p { font-family: Courier; }</style>"
heading = disclaimer_0 + disclaimer_1
display(HTML(heading))
# Out:
# <p>* values in 'shares' column are class frequencies in train dataset</p><style>p { font-size: 20px}p { font-family: Courier; }</style><p>** all values are normalized to [0, 100] range</p><style>p { font-size: 20px}p { font-family: Courier; }</style>
