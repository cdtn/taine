# %% [markdown]
# # Models metrics comparison

# %%
import os
import sys
import json

sys.path.insert(0, '../src')

import numpy as np
import pandas as pd

from loader import ImagesDataset

# %%
SEED = 11
rng = np.random.default_rng(SEED)

# %%
DATA_PATH = '../images'
SHAPE = (128, 128, 3)

dataset = ImagesDataset(path=DATA_PATH, preload=False, encode_labels=True)
classes = dataset.label_encoder.classes_.tolist()
n_classes = len(classes)

dataset.split(shuffle=SEED)

train_uniques, train_counts = np.unique(dataset.labels[dataset.train.indices], return_counts=True)
train_shares = train_counts / train_counts.sum()
# Out:
# 100%|████████████████████████████████████████████| 9/9 [00:00<00:00, 446.02it/s]

# %%
classwise_metrics = ['precision', 'recall']
general_metrics = ['accuracy', 'f1_score']
metrics_names = classwise_metrics + general_metrics

metrics = {name: {} for name in metrics_names}

METRICS_PATH = '../metrics'
for file in sorted(os.listdir(METRICS_PATH)):
    if not file.endswith('.json'):
        continue

    file_path = os.path.join(METRICS_PATH, file)
    with open(file_path, 'r') as f:
        metrics_dict = json.load(f)
    
    model_name = file.split('.')[0].split('_')[1]
    for name in metrics_names:
        metrics[name][model_name] = metrics_dict[name]

# %%
html = ''

styles = [
    {
        'selector': "caption",
        'props': [
            ('font-family', 'monospace'),
            ("font-size", "150%")
        ]
    },
    {
        'selector': "tbody",
        'props': [
            ('font-family', 'monospace'),
            ('text-align', 'right'),
        ]
    },
]

for metrics_name in metrics_names:
    metrics_dict = metrics[metrics_name]

    if metrics_name in classwise_metrics:
        metrics_dict = {'shares': train_shares, **metrics_dict}
        index = classes
    else:
        metrics_dict = {'shares': 1 / n_classes, **metrics_dict}
        index = ['\u00A0' * 3 + 'altogether']

    df = pd.DataFrame(data=metrics_dict, index=index)
    formatter = lambda value: f"{(value * 100).round(1)}"
    styled_df = df.style.background_gradient('RdYlGn', vmin=0, vmax=1, axis=0).format(formatter).set_caption(metrics_name).set_table_styles(styles)
    display(styled_df)
    
    html += styled_df.render()
    
with open('../report/report.html', 'w') as f:
    f.write(html)
# Out:
# <style  type="text/css" >
#     #T_9b61e71e_53a6_11ed_a8ce_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_9b61e71e_53a6_11ed_a8ce_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col0{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col1{
#             background-color:  #c82227;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col3{
#             background-color:  #84ca66;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col4,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col4{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col5,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col6{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row0_col7{
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col1{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col2{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col3,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col7{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col4{
#             background-color:  #96d268;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col5{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col6{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row1_col7,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col5{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col1{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col3{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col4{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col5{
#             background-color:  #eef8a8;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row2_col6{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col0,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col1{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col1{
#             background-color:  #d93429;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col2{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col3{
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col4,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col7{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col5,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col3{
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col6,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row3_col7{
#             background-color:  #b1de71;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col0{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col2{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col3{
#             background-color:  #48ae5c;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col4,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col3{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col5{
#             background-color:  #66bd63;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row4_col6{
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col0{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col1{
#             background-color:  #d22b27;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col2{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col3{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col4{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col6{
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row5_col7{
#             background-color:  #eff8aa;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col0{
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col1,#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col2{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col4{
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col5{
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col6{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row6_col7{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col0{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col2{
#             background-color:  #f67c4a;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col6{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_9b61e71e_53a6_11ed_a8ce_0242ac110002row7_col7{
#             background-color:  #2aa054;
#             color:  #000000;
#         }</style><table id="T_9b61e71e_53a6_11ed_a8ce_0242ac110002" ><caption>precision</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="co
# <style  type="text/css" >
#     #T_9b6a07e6_53a6_11ed_a8ce_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_9b6a07e6_53a6_11ed_a8ce_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col0{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col1{
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col2{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col3,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col4,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col5,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col5,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col6,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col7{
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col6,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col7{
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col1{
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col2{
#             background-color:  #ee613e;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col3{
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col4{
#             background-color:  #60ba62;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col5{
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col6,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row1_col7{
#             background-color:  #45ad5b;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col0{
#             background-color:  #eb5a3a;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col1{
#             background-color:  #ec5c3b;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col2{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col3,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col5{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col4{
#             background-color:  #a7d96b;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col6{
#             background-color:  #afdd70;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row2_col7{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col0{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col1,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col0{
#             background-color:  #d42d27;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col2{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col3{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col4{
#             background-color:  #ecf7a6;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col6,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row3_col7{
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col0{
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col1{
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col2{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col3,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col7,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col4{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col4{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col5{
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col6{
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row4_col7,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col6{
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col0{
#             background-color:  #d02927;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col1,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col1,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col1{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col2{
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col3,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col5{
#             background-color:  #addc6f;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col4{
#             background-color:  #8ecf67;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row5_col6,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col3{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col0{
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col2{
#             background-color:  #e75337;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col3,#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col5{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row6_col4{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col2{
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col5{
#             background-color:  #69be63;
#             color:  #000000;
#         }#T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row7_col7{
#             background-color:  #84ca66;
#             color:  #000000;
#         }</style><table id="T_9b6a07e6_53a6_11ed_a8ce_0242ac110002" ><caption>recall</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >VGG+KMEANS</th>        <th class="col_heading level0 col5" >VGG+LGBM</th>        <th class="col_heading level0 col6" >EFFICIENTNET</th>        <th class="col_heading level0 col7" >EFFICIENTNET+KNN</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b6a07e6_53a6_11ed_a8ce_0242ac110002level0_row0" class="row_heading level0 row0" >ArtDeco</th>
#                         <td id="T_9b6a07e6_53a6_11ed_a8ce_0242ac110002row0_col0" class="data row0 col0" >4.7</td>
#                         <td id="T_9b6a07e6_53a6_11ed_a8ce_0242ac1100
# <style  type="text/css" >
#     #T_9b6f3388_53a6_11ed_a8ce_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_9b6f3388_53a6_11ed_a8ce_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col1{
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col2{
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col3{
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col4{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col5{
#             background-color:  #b7e075;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col6{
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col7{
#             background-color:  #addc6f;
#             color:  #000000;
#         }</style><table id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002" ><caption>accuracy</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >VGG+KMEANS</th>        <th class="col_heading level0 col5" >VGG+LGBM</th>        <th class="col_heading level0 col6" >EFFICIENTNET</th>        <th class="col_heading level0 col7" >EFFICIENTNET+KNN</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col1" class="data row0 col1" >17.6</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col2" class="data row0 col2" >27.8</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col3" class="data row0 col3" >65.8</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col4" class="data row0 col4" >67.3</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col5" class="data row0 col5" >66.5</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col6" class="data row0 col6" >67.0</td>
#                         <td id="T_9b6f3388_53a6_11ed_a8ce_0242ac110002row0_col7" class="data row0 col7" >68.4</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_9b7330b4_53a6_11ed_a8ce_0242ac110002 caption {
#           font-family: monospace;
#           font-size: 150%;
#     }    #T_9b7330b4_53a6_11ed_a8ce_0242ac110002 tbody {
#           font-family: monospace;
#           text-align: right;
#     }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col0{
#             background-color:  #de402e;
#             color:  #f1f1f1;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col1{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col2{
#             background-color:  #fa9656;
#             color:  #000000;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col3{
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col4{
#             background-color:  #bfe47a;
#             color:  #000000;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col5,#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col7{
#             background-color:  #c5e67e;
#             color:  #000000;
#         }#T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col6{
#             background-color:  #cdea83;
#             color:  #000000;
#         }</style><table id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002" ><caption>f1_score</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shares</th>        <th class="col_heading level0 col1" >GUESS</th>        <th class="col_heading level0 col2" >LOGISTIC</th>        <th class="col_heading level0 col3" >VGG</th>        <th class="col_heading level0 col4" >VGG+KMEANS</th>        <th class="col_heading level0 col5" >VGG+LGBM</th>        <th class="col_heading level0 col6" >EFFICIENTNET</th>        <th class="col_heading level0 col7" >EFFICIENTNET+KNN</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002level0_row0" class="row_heading level0 row0" >   altogether</th>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col0" class="data row0 col0" >12.5</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col1" class="data row0 col1" >14.2</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col2" class="data row0 col2" >26.2</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col3" class="data row0 col3" >64.5</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col4" class="data row0 col4" >65.2</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col5" class="data row0 col5" >64.0</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col6" class="data row0 col6" >62.3</td>
#                         <td id="T_9b7330b4_53a6_11ed_a8ce_0242ac110002row0_col7" class="data row0 col7" >63.9</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Conlusion

# %% [markdown]
# Clustering of embeddings produces the highest metrics values so far, in both accuracy and F1 score. The latter is basically a harmonic mean of precision and recall, so with no extra assumptions about specific classes importance (e.g. errors on smaller classes must be minimized at all costs).
#
# 🥇 The first place is shared between two clustering approaches — KMeans on VGG embeddings and KNN on EfficientNet ones. First one is 1.3% better in terms of F1-score, while the latter is 1.1% better in terms of Accuracy. Choose your figther depending on what you wish to achieve.
#
# 🥈 The honorable second place is also taken by two participant — a pure VGG itself and the LGBM trained on that VGG embeddings. Vanilla convnet classification beats boosting on 0.5% in F1-score, while losing a 0.7% in terms of Accuracy.
#
# 🥉 Finally, third place goes to EfficientNet. It does well in general Accuracy, but fails miserably when it comes to F1-score. And it also deals kinda bad with rare classes, like _cartoon_ and _ArtDeco_.

# %% [markdown]
# ### Criticism

# %% [markdown]
# There are much more here to test and research. Among most important, yet not implemented ideas are:
#
# - Validate as a pro:
#     - Metrics above are obtained on a single fixed seed and therefore estimate of model performance quality based solely on them is kinda weak;
#     - Moreover no extra validation subset was allocated due, which also raises some questions on overfitting;
#     - Finally, what'll make those metrics a descent approximation of what we should expect from trained models _in production_, when confronted with real data, is definitely __cross-validation__. This fella, while being rather greedy on your resources (effectively increase computation time proportional to the total amount of train-test splits combination), is the most reliable source of information about quality of your model.
# - Enrich the data:
#     - The dataset is small and even simple augmentations like flip, rotate, cutout, crop and noise might significantly enrich it and therefore, increase model generalizing capability and reduce overfitting;
#     - Also, there are open datasets out there containing images of various styles (e.g. ArtGan). They might contribute a lot;
# - Research hyperparameters:
#     - Parametrization fixed in presented experiments is obtained via short-time research on limited parameters domain. More detailed and long research in some kind of Optuna or whatever, might bring you a few metrics percents.
# - Try more architectures and algorithms:
#     - Only a few of many existing neural networks architectures were checked — others might be heavier, but also more performant. And vision transformers are also a thing.
#     - There also more of a clustering, then just KMeans and KNN. Go for DBSCAN, SOM, Affinity Propagation, Hierarchical clustering and many others. Some of them might cluster images embeddings just due to the nature of that data. Low variance of features in poorly represented classes means that choosing like one fixed number (n_clusters or n_neighbors) and expect the clustering algorithm to perform equally good on different-sized clustergs, is rather naive. Instead, some kind of class-specific parameter should be accounted while clustering. Just be sure not to overfit on test subset. That why you need a validation set.
